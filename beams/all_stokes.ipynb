# %%
# %load_ext autoreload
# %autoreload 2
import lusee
import os
import healpy as hp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# let's work with 2 port fits files

fname = os.environ['LUSEE_DRIVE_DIR']+"Simulations/BeamModels/LanderRegolithComparison/eight_layer_regolith/hfss_lbl_3m_75deg.2port.fits"

BX = lusee.Beam(fname)
BY = BX.rotate(90)

# %%
Nside = 128
IX, QX, UX, VX, = BX.power_hp(30,Nside,20,stokes=True)
IY, QY, UY, VY, = BY.power_hp(30,Nside,20,stokes=True)
IC, QC, UC, VC, = BX.power_hp(30,Nside,20,stokes=True, cross=BY)

# %%
hp.mollview(np.real(VC))
