# %%
# %load_ext autoreload
# %autoreload 2
import lusee
from lusee.Simulation import mean_alm
import healpy as hp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
Nside = 64

# %%
beam1 = lusee.BeamGauss(dec_deg=30,phi_deg=0,sigma_deg=20).power_hp(30,Nside,freq_ndx=0)
beam2 = lusee.BeamGauss(dec_deg=30,phi_deg=10,sigma_deg=15).power_hp(30,Nside,freq_ndx=0)
hp.mollview(beam1*beam2)

# %%
# Brute force
bf = (beam1*beam2).sum()/(2*np.pi)
# Harmonic
ha = mean_alm(beam1,beam2,Nside*3)
print (bf,ha)
# Out:
# 76.21817781032074 76.21817721148169
